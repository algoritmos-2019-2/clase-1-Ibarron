# %%
from numpy import *
from scipy.integrate import *
from pylab import *
# %matplotlib inline

# %% [markdown]
# El módulo o paqueteria de la FFT es/ pasa de espacios de tiempo a a espacios de frecuencia
# Muy corto con muchos puntos se ve fina, muy larga con pocos puntos fea
#
# parseval
#
# hint: tiempo largo que se pueda mostrear durante mucho tiempo.

# %%
np.fft?

# %%
np.fft.fft?

# %%
t= linspace(0.0,10*pi,1001)
t
# Out:
# array([ 0.        ,  0.03141593,  0.06283185, ..., 31.35309468,
#        31.38451061, 31.41592654])

# %%
f = lambda x: sin(x)
f(t)
# Out:
# array([ 0.00000000e+00,  3.14107591e-02,  6.27905195e-02, ...,
#        -6.27905195e-02, -3.14107591e-02, -1.22464680e-15])

# %%
f1 = lambda x: sin(x) +3*cos(5*x)
f(t)
# Out:
# array([ 0.00000000e+00,  3.14107591e-02,  6.27905195e-02, ...,
#        -6.27905195e-02, -3.14107591e-02, -1.22464680e-15])

# %%
plot (t,f(t))

# %%
plot (t,f1(t))

# %%
np.fft.fft(f(t))
# Out:
# array([-2.92821323e-15+0.j        ,  6.53083368e-04-0.20809009j,
#         2.98463709e-03-0.47548852j, ...,  8.80746554e-03+0.93540798j,
#         2.98463709e-03+0.47548852j,  6.53083368e-04+0.20809009j])

# %%
a=np.fft.rfft(f(t))

# %%
b=np.fft.rfft(f1(t))

# %%
b.real
# Out:
# array([ 3.00000000e+00,  3.00543144e+00,  3.02219021e+00,  3.05237006e+00,
#         3.10610158e+00,  1.09736383e+01,  3.13058268e+00,  3.22147412e+00,
#         3.31427323e+00,  3.42109627e+00,  3.54677173e+00,  3.69569570e+00,
#         3.87310435e+00,  4.08580499e+00,  4.34302152e+00,  4.65765381e+00,
#         5.04833765e+00,  5.54302870e+00,  6.18563908e+00,  7.04927911e+00,
#         8.26530755e+00,  1.00956856e+01,  1.31488425e+01,  1.92351423e+01,
#         3.72299651e+01,  1.49607619e+03, -3.76132206e+01, -1.82136531e+01,
#        -1.18647227e+01, -8.71652357e+00, -6.83869340e+00, -5.59317865e+00,
#        -4.70784721e+00, -4.04706963e+00, -3.53567235e+00, -3.12863337e+00,
#        -2.79734527e+00, -2.52276115e+00, -2.29171001e+00, -2.09479424e+00,
#        -1.92512942e+00, -1.77755754e+00, -1.64813830e+00, -1.53381020e+00,
#        -1.43215888e+00, -1.34125499e+00, -1.25953847e+00, -1.18573444e+00,
# ...

# %%
a.real
# Out:
# array([-2.92821323e-15,  6.53083368e-04,  2.98463709e-03,  8.80746554e-03,
#         2.77686240e-02,  7.84941099e+00, -5.16384897e-02, -3.21347684e-02,
#        -2.58081546e-02, -2.27388912e-02, -2.09562066e-02, -1.98072721e-02,
#        -1.90143859e-02, -1.84399304e-02, -1.80082371e-02, -1.76744267e-02,
#        -1.74102986e-02, -1.71973050e-02, -1.70227871e-02, -1.68778363e-02,
#        -1.67560191e-02, -1.66525856e-02, -1.65639611e-02, -1.64874100e-02,
#        -1.64208076e-02, -1.63624818e-02, -1.63111013e-02, -1.62655944e-02,
#        -1.62250903e-02, -1.61888753e-02, -1.61563594e-02, -1.61270515e-02,
#        -1.61005401e-02, -1.60764777e-02, -1.60545699e-02, -1.60345653e-02,
#        -1.60162482e-02, -1.59994332e-02, -1.59839593e-02, -1.59696871e-02,
#        -1.59564945e-02, -1.59442749e-02, -1.59329346e-02, -1.59223906e-02,
#        -1.59125700e-02, -1.59034077e-02, -1.58948460e-02, -1.58868334e-02,
# ...

# %%
type(a)
# Out:
# numpy.ndarray

# %%
len(t)
# Out:
# 1001

# %%
len(a)
# Out:
# 501

# %%
plot (t[0:501],a)
# Out:
# /home/ibarron/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py:501: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plot(t[0:501],b)
xlim(-2,5)
# Out:
# (-2, 5)

# %% [markdown]
# Se grafica con la frecuencia, si te tomas el inverso del tiempo te tomas una base para tu frecuencia partida por todo lso pedazos

# %%
def fft_w(x,ffx):
    n=len(ffx)
    delta_x = x[1] - x[0]
    omega= linspace(0,1.0/delta_x, n/2 + 1)
    omega= omega*pi
    T=np.fft.rfft(ffx)/n
    espectro= abs (T)
    return omega, espectro

# %%
omega, I= fft_w(t,f1(t))
# Out:
# /home/ibarron/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   after removing the cwd from sys.path.

# %%
plot (omega,I)
xlim (0,6)
# Out:
# (0, 6)

# %%
5/(2*pi)
# Out:
# 0.7957747154594768

# %%
def oscilador(x,t,p0,p1,p2,p3):
    return [x[1],-2*p0*x[1]-(p1**2)*x[0]+p2*sin(p3*t)]

# %%
ti=linspace (0, 150*pi, 100001)

# %%
xout = odeint(oscilador,[1.0,0.0],t,args=(.05,1,0.0, 2.0))

# %%
plot (t, xout[:,0])

# %%
xout[:,0]
# Out:
# array([1.        , 0.99950708, 0.99803086, ..., 0.20638547, 0.2069508 ,
#        0.20731044])

# %%
fa, espe= fft_w(t,xout[:,0])
# Out:
# /home/ibarron/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   after removing the cwd from sys.path.

# %%
plot(fa, espe)
xlim(0,10)
# Out:
# (0, 10)
